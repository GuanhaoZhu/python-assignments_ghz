# %%
# 1) What is the output of the following code and why? 

# var1 = 1
# var2 = 2
# var3 = "3"

# print(var1 + var2 + var3)

# a) 6 
# b) 33 
# c) 3 + 3
d) Error # unsupported operand type(s) for +: 'int' and 'str'

# %%
# 2) What is the output of the following code? 

# str = "pynative"

# print (str[1:3])

# a) py 
b) yn 
# c) pyn
# d) yna

# %%
# 3) What is the output of the following code? 

# var= "James Bond"
# print(var[2::-1])

# a) Jam
# b) dno
c) maJ # start from 2, and go back 
# d) dnoB semaJ

# %%
# 4) What is the output of the following code? 

# var = "James" * 2  * 3
# print(var)

a) JamesJamesJamesJamesJamesJames 
# b) JamesJamesJamesJamesJames
# c) Error: invalid syntax

# %%
# 5) Get rid of the non fruit item: 

# sweets = ['apple', 'bananas', 'canteloupes', 'donut']

sweets = ['apple', 'bananas', 'canteloupes', 'donut']
sweets.pop(3)

print(sweets)

# %%
# 6) Find "santa" in the variable "house" 


# room1=['gabe', 'greg']
# room2=['michelle','santa','stacey']
# room3=['adam','sam', 'melissa']
# house= [room2, room1, room3] 

room2 = ['michelle','santa','stacey']
print(room2[1])

# %%
# 7) A dictionary is the best way to store a sequence of events like a recipe.

# True or false? 
 
False # String would be better?

# %%
# 8) Remove all dupes 
# names = ['mary', 'bob', 'jessica', 'pierre', 'bob', 'jennifer', 'chris', 
#          'christina', 'tina', 'mary', 'tina', 'bob', 'michelle','jennifer']

names = ['mary', 'bob', 'jessica', 'pierre', 'bob', 'jennifer', 'chris', 'christina', 'tina', 'mary', 'tina', 'bob', 'michelle','jennifer']

new_list = []
for one_name in names:
    if one_name not in new_list:
        new_list.append(one_name)

print(new_list)

# or

[new_list.append(one_name) for one_name in names if one_name not in new_list]
print(new_list)

# %%
# 9) What's the difference between = and == ? 

= simple assignment
== equal or not

# %%
# 10) 

# Use the concepts you learned in class to construct a poem. Please make sure you write your own poem. There are no guidelines to writing this poem but if you want, feel free to following traditional poem formats like ballads, sonnets, haikus or more.  

# See below for example. I expect yours to have a bit more elegant. 

# Credit Poem: "Still I Rise" by Maya Angelou 

# Reference: https://www.popwebdesign.net/popart_blog/en/2018/01/code-poetry-poems-written-in-programming-languages/

# %%
a = "I Rise"
b = "by maya angelou"

print (f'Still {a}')
print('\n')
print(b.upper())
print('\n')
print('With your bitter, twisted lies,')
print('You may trod me in the very dirt')
print("But still, like dust, I'll rise.")
print('\n')
print('Does my sassiness upset you?')
print('Why are you beset with gloom?')
print("’Cause I walk like I've got oil wells")
print('Pumping in my living room.')
print('\n')
print('Just like moons and like suns,')
print('With the certainty of tides,')
print('Just like hopes springing high,')
print("Still I'll rise.")
print('\n')
print('Did you want to see me broken?')
print('Bowed head and lowered eyes?')
print('Shoulders falling down like teardrops,')
print('Weakened by my soulful cries?')
print('\n')
print('Does my haughtiness offend you?')
print("Don't you take it awful hard")
print("’Cause I laugh like I've got gold mines")
print('Diggin’ in my own backyard.')
print('\n')
print('You may shoot me with your words,')
print('You may cut me with your eyes,')
print('You may kill me with your hatefulness,')
print('But still, like air, I’ll rise.')
print('\n')
print('Does my sexiness upset you?')
print('Does it come as a surprise')
print("That I dance like I've got diamonds")
print('At the meeting of my thighs?')
print('\n')
print('Out of the huts of history’s shame')
print (f'{a}')
print('Up from a past that’s rooted in pain')
print (f'{a}')
print("I'm a black ocean, leaping and wide,")
print('Welling and swelling I bear in the tide.')
print('\n')
print('Leaving behind nights of terror and fear')
print (f'{a}')
print('Into a daybreak that’s wondrously clear')
print (f'{a}')
print('Bringing the gifts that my ancestors gave,')
print('I am the dream and the hope of the slave.')
print (f'{a}')
print (f'{a}')
print (f'{a}.')
# Out:
# Still I Rise
#
#
# BY MAYA ANGELOU
#
#
# With your bitter, twisted lies,
# You may trod me in the very dirt
# But still, like dust, I'll rise.
#
#
# Does my sassiness upset you?
# Why are you beset with gloom?
# ’Cause I walk like I've got oil wells
# Pumping in my living room.
#
#
# Just like moons and like suns,
# With the certainty of tides,
# Just like hopes springing high,
# Still I'll rise.
#
#
# Did you want to see me broken?
# Bowed head and lowered eyes?
# Shoulders falling down like teardrops,
# Weakened by my soulful cries?
#
#
# Does my haughtiness offend you?
# Don't you take it awful hard
# ’Cause I laugh like I've got gold mines
# Diggin’ in my own backyard.
#
#
# You may shoot me with your words,
# You may cut me with your eyes,
# You may kill me with your hatefulness,
# But still, like air, I’ll rise.
#
#
# Does my sexiness upset you?
# Does it come as a surprise
# That I dance like I've got diamonds
# At the meeting of my thighs?
#
#
# Out of the huts of history’s shame
# I Rise
# Up from a past that’s rooted in pain
# I Rise
# I'm a black ocean, leaping and wide,
# Welling and swelling I bear in the tide.
#
#
# Leaving behind nights of terror and fear
# I Rise
# Into a daybreak that’s wondrously clear
# I Rise
# Bringing the gifts that my ancestors gave,
# I am the dream and the hope of the slave.
# I Rise
# I Rise
# I Rise.

# %%
import random

title = 'How do we turn on the light?'
author = 'Guanhao Zhu'
date = 'Jan. 2023'
a = ['Making fire','Using candlesticks','Kerosene lamps']
perm1 = 'and Mastering electricity.'
b = ['A lever','A switch','A knob']
perm2 = 'or a button.'
c = ['We pull', 'We click', 'We scroll']
perm_dance = 'and We dance.'
d = ['On the wall','In the rooms','On your hands']
perm3 = 'In my eyes.'
e = ['Rough','Sparkling','Smooth']
perm4 = 'or Dizzying.'
f = ['Rhythmic','Mellow','Calm']
perm5 = 'or Melodic.'
g = ['We scratch','We shout','We boounce']
h = ['blown','stretched','stitched']
perm6 = 'or sculpted.'
i = ["dynamic",'concrete','resilient',]
perm7 = 'or streamlined.'
j = ['We sing','We lie down','We smile']

random.shuffle(a)
random.shuffle(b)
random.shuffle(c)
random.shuffle(d)
random.shuffle(e)
random.shuffle(f)
random.shuffle(g)
random.shuffle(h)
random.shuffle(i)
random.shuffle(j)

print(title.upper() + '\n' + 'written by '+ author + '\n')
print(title.upper())

A_items = "" #initializing
B_items = ""
C_items = ""
D_items = ""
E_items = ""
F_items = ""
G_items = ""
H_items = ""
I_items = ""
J_items = ""

for itemA in a:
    A_items = A_items + itemA + ", "
print(A_items + perm1)

for itemB in b:
    B_items = B_items + itemB + ", "
print(B_items + perm2)

for itemC in c:
    C_items = C_items + itemC + ", "
print(C_items + perm_dance)

print('\n')

print(title.upper())
for itemD in d:
    D_items = D_items + itemD + ", "
print(D_items + perm3)

for itemE in e:
    E_items = E_items + itemE + ", "
print(E_items + perm4)

for itemF in f:
    F_items = F_items + itemF + ", "
print(F_items + perm5)

for itemG in g:
    G_items = G_items + itemG + ", "
print(G_items + perm_dance)

print('\n')
print(title.upper())

for itemH in h:
    H_items = H_items + itemH + ", "
print('It could be ' + H_items + perm6)

for itemI in i:
    I_items = I_items + itemI + ", "
print("It's " + I_items + perm7)

for itemJ in j:
    J_items = J_items + itemJ + ", "
print(J_items + perm_dance)
# Out:
# HOW DO WE TURN ON THE LIGHT?
# written by Guanhao Zhu
#
# HOW DO WE TURN ON THE LIGHT?
# Using candlesticks, Making fire, Kerosene lamps, and Mastering electricity.
# A switch, A lever, A knob, or a button.
# We click, We pull, We scroll, and We dance.
#
#
# HOW DO WE TURN ON THE LIGHT?
# In the rooms, On the wall, On your hands, In my eyes.
# Smooth, Sparkling, Rough, or Dizzying.
# Mellow, Calm, Rhythmic, or Melodic.
# We shout, We scratch, We boounce, and We dance.
#
#
# HOW DO WE TURN ON THE LIGHT?
# It could be blown, stretched, stitched, or sculpted.
# It's dynamic, resilient, concrete, or streamlined.
# We sing, We lie down, We smile, and We dance.
